# %% [markdown]
# # Get the Stock Code of the stock
# - Stock codes are used because they provide a unique identifier for each stock
# - download a pdf file "List_of_Companies_2022.06.24__Website_.pdf"
# from : https://www.bursamalaysia.com/sites/5d809dcf39fba22790cad230/assets/62b573f45b711a4597eb7706/List_of_Companies_2022.06.24__Website_.pdf
#
# ### Import libaries

# %%
import tabula
import pandas as pd

# %%
# Read the first page and specify the header
dfs = tabula.read_pdf("List_of_Companies_2022.06.24__Website_.pdf", pages='2-25', lattice=True)

# Loop through the list of DataFrames and remove the first two rows from each
dfs = [df.iloc[1:] for df in dfs]

# Concatenate the DataFrames into a single DataFrame
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#      LISTING TEAM IN CHARGE                         Unnamed: 0 Unnamed: 1  \
# 0                         1  7-ELEVEN MALAYSIA HOLDINGS BERHAD       5250
# 1                         2       ABF MALAYSIA BOND INDEX FUND     0800EA
# 2                         3                 ABLE GLOBAL BERHAD       7167
# 3                         4                   ABLEGROUP BERHAD       7086
# 4                         5                  ABM FUJIYA BERHAD       5198
# ...                     ...                                ...        ...
# 996                     997             YX PRECIOUS METALS BHD       0250
# 997                     998                       ZECON BERHAD       7028
# 998                     999                       ZELAN BERHAD       2283
# 999                    1000      ZEN TECH INTERNATIONAL BERHAD       0094
# 1000                   1001         ZHULIAN CORPORATION BERHAD       5131
#
#      Unnamed: 2
# 0             3
# 1             2
# 2             3
# 3             2
# 4             2
# ...         ...
# 996           4
# 997           1
# 998           1
# 999           4
# 1000          3
#
# [1001 rows x 4 columns]

# %%
# delete columns that are not needed
del df['LISTING TEAM IN CHARGE']
del df['Unnamed: 2']

# %%
df
# Out:
#                              Unnamed: 0 Unnamed: 1
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD       5250
# 1          ABF MALAYSIA BOND INDEX FUND     0800EA
# 2                    ABLE GLOBAL BERHAD       7167
# 3                      ABLEGROUP BERHAD       7086
# 4                     ABM FUJIYA BERHAD       5198
# ...                                 ...        ...
# 996              YX PRECIOUS METALS BHD       0250
# 997                        ZECON BERHAD       7028
# 998                        ZELAN BERHAD       2283
# 999       ZEN TECH INTERNATIONAL BERHAD       0094
# 1000         ZHULIAN CORPORATION BERHAD       5131
#
# [1001 rows x 2 columns]

# %%
# rename the column headers
df.rename(columns = {'Unnamed: 0': 'stock_name', 'Unnamed: 1': 'stock_code'}, inplace = True)

# %%
df
# Out:
#                              stock_name stock_code
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD       5250
# 1          ABF MALAYSIA BOND INDEX FUND     0800EA
# 2                    ABLE GLOBAL BERHAD       7167
# 3                      ABLEGROUP BERHAD       7086
# 4                     ABM FUJIYA BERHAD       5198
# ...                                 ...        ...
# 996              YX PRECIOUS METALS BHD       0250
# 997                        ZECON BERHAD       7028
# 998                        ZELAN BERHAD       2283
# 999       ZEN TECH INTERNATIONAL BERHAD       0094
# 1000         ZHULIAN CORPORATION BERHAD       5131
#
# [1001 rows x 2 columns]

# %% [markdown]
# ### Remove duplicate stock code

# %%
df[df['stock_code']=='5235SS']
# Out:
#                             stock_name stock_code
# 444      KLCC PROPERTY HOLDINGS BERHAD     5235SS
# 445  KLCC REAL ESTATE INVESTMENT TRUST     5235SS

# %%
df = df.drop_duplicates(subset='stock_code')

# %%
df[df['stock_code']=='5235SS']
# Out:
#                         stock_name stock_code
# 444  KLCC PROPERTY HOLDINGS BERHAD     5235SS

# %%
df
# Out:
#                              stock_name stock_code
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD       5250
# 1          ABF MALAYSIA BOND INDEX FUND     0800EA
# 2                    ABLE GLOBAL BERHAD       7167
# 3                      ABLEGROUP BERHAD       7086
# 4                     ABM FUJIYA BERHAD       5198
# ...                                 ...        ...
# 996              YX PRECIOUS METALS BHD       0250
# 997                        ZECON BERHAD       7028
# 998                        ZELAN BERHAD       2283
# 999       ZEN TECH INTERNATIONAL BERHAD       0094
# 1000         ZHULIAN CORPORATION BERHAD       5131
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Remove all the delisted stock code
#
# - delisted stock : ['03009', '0400GA', '7206', '6548', '2925', '0401GA', '9474', '0400GB', '7205', '8761']

# %%
delisted_stock=['03009', '0400GA', '7206', '6548', '2925', '0401GA', '9474', '0400GB', '7205', '8761']

# %%
# remove rows that contain any of the values in the list
df = df[~df['stock_code'].isin(delisted_stock)]
df
# Out:
#                              stock_name stock_code
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD       5250
# 1          ABF MALAYSIA BOND INDEX FUND     0800EA
# 2                    ABLE GLOBAL BERHAD       7167
# 3                      ABLEGROUP BERHAD       7086
# 4                     ABM FUJIYA BERHAD       5198
# ...                                 ...        ...
# 996              YX PRECIOUS METALS BHD       0250
# 997                        ZECON BERHAD       7028
# 998                        ZELAN BERHAD       2283
# 999       ZEN TECH INTERNATIONAL BERHAD       0094
# 1000         ZHULIAN CORPORATION BERHAD       5131
#
# [990 rows x 2 columns]

# %% [markdown]
# # Connect to database
# - load stock information(stock code , stock name) into database
#
# ### Import libraries

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote

# %% [markdown]
# ### Connect to database
# - connecting to a PostgreSQL database using the psycopg2 library
#
# ##### Steps
# 1. Create a database in PostgreSQL
# 2. The connection string follows the standard format for connecting to a PostgreSQL database using SQLAlchemy. It consists of the following elements:
#
#     - 'postgresql://': the dialect and driver for SQLAlchemy to use for the connection.
#     - 'postgres': the username to use for the connection.
#     - '%s': a placeholder for the password to use for the connection.
#     - '@localhost': the hostname of the database server to connect to.
#     - '/dividend_investing_no2': the name of the database to connect to.
#     - The password for the connection is passed to the quote function from the urllib library, which adds URL encoding to the string (e.g. replacing special characters with %-encoded equivalents). The result of the quote function is then used to replace the %s placeholder in the connection string.

# %%
conn_string = 'postgresql://postgres:%s@localhost/dividend_investing_no2'% quote('@SMWHot4')

# %%
db = create_engine(conn_string)
conn = db.connect()

# %% [markdown]
# ###  write a pandas DataFrame (df) to a PostgreSQL database, and then retrieve and print the data stored in the database.

# %%
df.to_sql('stock_info', con=conn, if_exists='replace',
          index=False)
conn = psycopg2.connect(conn_string
                        )
conn.autocommit = True
cursor = conn.cursor()

sql1 = '''select * from stock_info;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)

conn.commit()
conn.close()
# Out:
# ('7-ELEVEN MALAYSIA HOLDINGS BERHAD', '5250')
# ('ABF MALAYSIA BOND INDEX FUND', '0800EA')
# ('ABLE GLOBAL BERHAD', '7167')
# ('ABLEGROUP BERHAD', '7086')
# ('ABM FUJIYA BERHAD', '5198')
# ('ACE INNOVATE ASIA BERHAD', '03028')
# ('ACME HOLDINGS BERHAD', '7131')
# ('ACO GROUP BERHAD', '0218')
# ('ADVANCE INFORMATION MARKETING BERHAD', '0122')
# ('ADVANCE SYNERGY BERHAD', '1481')
# ('ADVANCECON HOLDINGS BERHAD', '5281')
# ('ADVANCED PACKAGING TECHNOLOGY (M) BHD', '9148')
# ('ADVENTA BERHAD', '7191')
# ('AE MULTI HOLDINGS BERHAD', '7146')
# ('AEMULUS HOLDINGS BERHAD', '0181')
# ('AEON CO. (M) BHD', '6599')
# ('AEON CREDIT SERVICE (M) BERHAD', '5139')
# ('AFFIN BANK BERHAD', '5185')
# ('AGESON BERHAD', '7145')
# ('AHB HOLDINGS BERHAD', '7315')
# ('AHMAD ZAKI RESOURCES BERHAD', '7078')
# ('AIMFLEX BERHAD', '0209')
# ('AIRASIA X BERHAD', '5238')
# ('AJINOMOTO (MALAYSIA) BERHAD', '2658')
# ('AJIYA BERHAD', '7609')
# ('AL-`AQAR HEALTHCARE REIT', '5116')
# ('ALAM MARITIM RESOURCES BERHAD', '5115')
# ('ALCOM GROUP BERHAD', '2674')
# ('ALDRICH RESOURCES BERHAD', '0079')
# ('ALLIANCE BANK MALAYSIA BERHAD', '2488')
# ('ALLIANZ MALAYSIA BERHAD', '1163')
# ('ALPHA OCEAN RESOURCES BERHAD', '03051')
# ('AL-SALAM REAL ESTATE INVESTMENT TRUST', '5269')
# ('AMANAHRAYA REAL ESTATE INVESTMENT TRUST', '5127')
# ('AME ELITE CONSORTIUM BERHAD', '5293')
# ('AMFIRST REAL ESTATE INVESTMENT TRUST', '5120')
# ('AMLEX HOLDINGS BERHAD', '03011')
# ('AMMB HOLDINGS BERHAD', '1015')
# ('AMTEL HOLDINGS BERHAD', '7031')
# ('AMWAY (MALAYSIA) HOLDINGS BERHAD', '6351')
# ('ANALABS RESOURCES BERHAD', '7083')
# ('ANCOM LOGISTICS BERHAD', '0048')
# ('ANCOM NYLEX BERHAD', '4758')
# ('ANEKA JARINGAN HOLDINGS BERHAD', '0226')
# ('ANN JOO RESOURCES BERHAD', '6556')
# ('ANNUM BERHAD', '5082')
# ('ANZO HOLDINGS BERHAD', '9342')
# ('APB RESOURCES BERHAD', '5568')
# ('APEX EQUITY HOLDINGS BERHAD', '5088')
# ('APEX HEALTHCARE BERHAD', '7090')
# ('APM AUTOMOTIVE HOLDINGS BERHAD', '5015')
# ('APOLLO FOOD HOLDINGS BERHAD', '6432')
# ('APPASIA BERHAD', '0119')
# ('A-RANK BERHAD', '7214')
# ('ARB BERHAD', '7181')
# ('ARK RESOURCES HOLDINGS BERHAD', '7007')
# ('ARTRONIQ BERHAD', '0038')
# ('ASDION BERHAD', '0068')
# ('ASIA BRANDS BERHAD', '7722')
# ('ASIA FILE CORPORATION BHD', '7129')
# ('ASIA MEDIA GROUP BERHAD', '0159')
# ('ASIA POLY HOLDINGS BERHAD', '0105')
# ('ASIAN PAC HOLDINGS BERHAD', '4057')
# ('ASTINO BERHAD', '7162')
# ('ASTRAL ASIA BERHAD', '7054')
# ('ASTRAMINA GROUP BERHAD', '03032')
# ('ASTRO MALAYSIA HOLDINGS BERHAD', '6399')
# ('AT SYSTEMATIZATION BERHAD', '0072')
# ('ATA IMS BERHAD', '8176')
# ('ATLAN HOLDINGS BHD', '7048')
# ('ATRIUM REAL ESTATE INVESTMENT TRUST', '5130')
# ('ATTA GLOBAL GROUP BERHAD', '7099')
# ('AURELIUS TECHNOLOGIES BERHAD', '5302')
# ('AURORA ITALIA INTERNATIONAL BERHAD', '03037')
# ('AVILLION BERHAD', '8885')
# ('AWANBIRU TECHNOLOGY BERHAD', '5204')
# ('AWC BERHAD', '7579')
# ('AXIATA GROUP BERHAD', '6888')
# ('AXIS REAL ESTATE INVESTMENT TRUST', '5106')
# ('AXTERIA GROUP BERHAD', '7120')
# ('AYER HOLDINGS BERHAD', '2305')
# ('AYS VENTURES BERHAD', '5021')
# ('B.I.G. INDUSTRIES BERHAD', '7005')
# ('BABA ECO GROUP BERHAD', '03012')
# ('BAHVEST RESOURCES BERHAD', '0098')
# ('BANK ISLAM MALAYSIA BERHAD', '5258')
# ('BARAKAH OFFSHORE PETROLEUM BERHAD', '7251')
# ('BATU KAWAN BERHAD', '1899')
# ('BCB BERHAD', '6602')
# ('BCM ALLIANCE BERHAD', '0187')
# ('BENALEC HOLDINGS BERHAD', '5190')
# ('BERJAYA ASSETS BERHAD', '3239')
# ('BERJAYA CORPORATION BERHAD', '3395')
# ('BERJAYA FOOD BERHAD', '5196')
# ('BERJAYA LAND BERHAD', '4219')
# ('BERMAZ AUTO BERHAD', '5248')
# ('BERTAM ALLIANCE BERHAD', '9814')
# ('BESHOM HOLDINGS BERHAD', '7668')
# ('BINA DARULAMAN BERHAD', '6173')
# ('BINA PURI HOLDINGS BHD', '5932')
# ('BINASAT COMMUNICATIONS BERHAD', '0195')
# ('BINTAI KINDEN CORPORATION BERHAD', '6998')
# ('BINTULU PORT HOLDINGS BERHAD', '5032')
# ('BIOALPHA HOLDINGS BERHAD', '0179')
# ('BLD PLANTATION BHD.', '5069')
# ('BOILERMECH HOLDINGS BERHAD', '0168')
# ('BONIA CORPORATION BERHAD', '9288')
# ('BORNEO OIL BERHAD', '7036')
# ('BOUSTEAD HEAVY INDUSTRIES CORPORATION BHD', '8133')
# ('BOUSTEAD HOLDINGS BERHAD', '2771')
# ('BOUSTEAD PLANTATIONS BERHAD', '5254')
# ('BOX-PAK (MALAYSIA) BERHAD', '6297')
# ('BP PLASTICS HOLDING BHD', '5100')
# ('BRIGHT PACKAGING INDUSTRY BERHAD', '9938')
# ('BRITE-TECH BERHAD', '0011')
# ('BRITISH AMERICAN TOBACCO (MALAYSIA) BERHAD', '4162')
# ('BSL CORPORATION BERHAD', '7221')
# ('BTM RESOURCES BERHAD', '7188')
# ('BUMI ARMADA BERHAD', '5210')
# ('BURSA MALAYSIA BERHAD', '1818')
# ('BV LAND HOLDINGS BERHAD', '03042')
# ('C.I. HOLDINGS BERHAD', '2828')
# ('CAB CAKARAN CORPORATION BERHAD', '7174')
# ('CABNET HOLDINGS BERHAD', '0191')
# ('CAELY HOLDINGS BHD', '7154')
# ('CAHYA MATA SARAWAK BERHAD', '2852')
# ('CAM RESOURCES BERHAD', '7128')
# ('CAN-ONE BERHAD', '5105')
# ('CAPITAL A BERHAD', '5099')
# ('CAPITALAND MALAYSIA TRUST', '5180')
# ('CAREPLUS GROUP BERHAD', '0163')
# ('CARIMIN PETROLEUM BERHAD', '5257')
# ('CARLSBERG BREWERY MALAYSIA BERHAD', '2836')
# ('CARZO HOLDINGS BERHAD', '03048')
# ('CATCHA DIGITAL BERHAD', '0173')
# ('CB INDUSTRIAL PRODUCT HOLDING BERHAD', '7076')
# ('CCK CONSOLIDATED HOLDINGS BERHAD', '7035')
# ('CE TECHNOLOGY BERHAD', '03024')
# ('CEKD BERHAD', '0238')
# ('CENGILD MEDICAL BERHAD', '0243')
# ('CENSOF HOLDINGS BERHAD', '5195')
# ('CENTRAL GLOBAL BERHAD', '8052')
# ('CEPATWAWASAN GROUP BERHAD', '8982')
# ('CHEETAH HOLDINGS BERHAD', '7209')
# ('CHIN HIN GROUP BERHAD', '5273')
# ('CHIN HIN GROUP PROPERTY BERHAD', '7187')
# ('CHIN TECK PLANTATIONS BERHAD', '1929')
# ('CHIN WELL HOLDINGS BERHAD', '5007')
# ('CHINA AUTOMOBILE PARTS HOLDINGS LIMITED', '5229')
# ('CHINA OUHUA WINERY HOLDINGS LIMITED', '5188')
# ('CHOO BEE METAL INDUSTRIES BHD', '5797')
# ('CHUAN HUAT RESOURCES BHD', '7016')
# ('CIMB GROUP HOLDINGS BERHAD', '1023')
# ('CITAGLOBAL BERHAD', '7245')
# ('CITRA NUSA HOLDINGS BERHAD', '5104')
# ('CJ CENTURY LOGISTICS HOLDINGS BERHAD', '7117')
# ('CLASSIC SCENIC BERHAD', '7202')
# ('CLOUDARON GROUP BERHAD', '03001')
# ('CME GROUP BERHAD', '7018')
# ('CN ASIA CORPORATION BHD', '7986')
# ('CNERGENZ BERHAD', '0246')
# ('COASTAL CONTRACTS BHD', '5071')
# ('COMFORT GLOVES BERHAD', '2127')
# ('COMINTEL CORPORATION BHD', '7195')
# ('COMPLETE LOGISTIC SERVICES BERHAD', '5136')
# ('COMPUGATES HOLDINGS BERHAD', '5037')
# ('COMPUTER FORMS (MALAYSIA) BERHAD', '8044')
# ('CONCRETE ENGINEERING PRODUCTS BERHAD', '8435')
# ('CORAZA INTEGRATED TECHNOLOGY BERHAD', '0240')
# ('COUNTRY HEIGHTS HOLDINGS BHD', '5738')
# ('COUNTRY VIEW BERHAD', '5049')
# ('CRESCENDO CORPORATION BERHAD', '6718')
# ('CREST BUILDER HOLDINGS BERHAD', '8591')
# ('CRG INCORPORATED BERHAD', '03016')
# ('CSC STEEL HOLDINGS BERHAD', '5094')
# ('CSH ALLIANCE BERHAD', '7165')
# ('CTOS DIGITAL BERHAD', '5301')
# ('CUSCAPI BERHAD', '0051')
# ('CWG HOLDINGS BERHAD', '9423')
# ('CYL CORPORATION BERHAD', '7157')
# ('CYPARK RESOURCES BERHAD', '5184')
# ('D & O GREEN TECHNOLOGIES BERHAD', '7204')
# ('DAGANG NEXCHANGE BERHAD', '4456')
# ('DAMANSARA HOLDINGS BERHAD', '3484')
# ('DANCOMECH HOLDINGS BERHAD', '5276')
# ('DATAPREP HOLDINGS BHD', '8338')
# ('DATASONIC GROUP BERHAD', '5216')
# ('DAYANG ENTERPRISE HOLDINGS BERHAD', '5141')
# ('DELEUM BERHAD', '5132')
# ('DESTINI BERHAD', '7212')
# ('DFCITY GROUP BERHAD', '5165')
# ('DGB ASIA BERHAD', '0152')
# ('DIALOG GROUP BERHAD', '7277')
# ('DIGI.COM BERHAD', '6947')
# ('DIGISTAR CORPORATION BERHAD', '0029')
# ('DIVFEX BERHAD', '0131')
# ('DKLS INDUSTRIES BHD', '7528')
# ('DKSH HOLDINGS (MALAYSIA) BERHAD', '5908')
# ("D'NONCE TECHNOLOGY BHD", '7114')
# ('DOLOMITE CORPORATION BERHAD', '5835')
# ('DOLPHIN INTERNATIONAL BERHAD', '5265')
# ('DOMINANT ENTERPRISE BERHAD', '7169')
# ('DPI HOLDINGS BERHAD', '0205')
# ('DPS RESOURCES BERHAD', '7198')
# ('DRB-HICOM BERHAD', '1619')
# ('DUFU TECHNOLOGY CORP. BERHAD', '7233')
# ('DUOPHARMA BIOTECH BERHAD', '7148')
# ('DUTALAND BERHAD', '3948')
# ('DUTCH LADY MILK INDUSTRIES BERHAD', '3026')
# ('DYNACIATE GROUP BERHAD', '5178')
# ('DYNAFRONT HOLDINGS BERHAD', '03046')
# ('E.A.TECHNIQUE (M) BERHAD', '5259')
# ('EA HOLDINGS BERHAD', '0154')
# ('EASTERN & ORIENTAL BERHAD', '3417')
# ('EASTLAND EQUITY BHD', '2097')
# ('ECM LIBRA GROUP BERHAD', '2143')
# ('ECO WORLD DEVELOPMENT GROUP BERHAD', '8206')
# ('ECO WORLD INTERNATIONAL BERHAD', '5283')
# ('ECOBUILT HOLDINGS BERHAD', '0059')
# ('ECOFIRST CONSOLIDATED BHD', '3557')
# ('ECOMATE HOLDINGS BERHAD', '0239')
# ('ECONFRAME BERHAD', '0227')
# ('ECONPILE HOLDINGS BERHAD', '5253')
# ('EDARAN BERHAD', '5036')
# ('EDEN INC. BERHAD', '7471')
# ('EDUSPEC HOLDINGS BERHAD', '0107')
# ('EFFICIENT E-SOLUTIONS BERHAD', '0064')
# ('EG INDUSTRIES BERHAD', '8907')
# ('EITA RESOURCES BERHAD', '5208')
# ('EKOVEST BERHAD', '8877')
# ('EKSONS CORPORATION BERHAD', '9016')
# ('ELK-DESA RESOURCES BERHAD', '5228')
# ('ELSOFT RESEARCH BERHAD', '0090')
# ('EMICO HOLDINGS BERHAD', '9091')
# ('ENCORP BERHAD', '6076')
# ('ENEST GROUP BERHAD', '03025')
# ('ENG KAH CORPORATION BERHAD', '7149')
# ('ENGTEX GROUP BERHAD', '5056')
# ('ENRA GROUP BERHAD', '8613')
# ('EONMETALL GROUP BERHAD', '7217')
# ('EP MANUFACTURING BHD', '7773')
# ('EQUITIESTRACKER HOLDINGS BERHAD', '03021')
# ('ES CERAMICS TECHNOLOGY BHD', '0100')
# ('ESTHETICS INTERNATIONAL GROUP BERHAD', '5081')
# ('EUPE CORPORATION BERHAD', '6815')
# ('EURO HOLDINGS BERHAD', '7208')
# ('EUROSPAN HOLDINGS BERHAD', '7094')
# ('EVERGREEN FIBREBOARD BERHAD', '5101')
# ('EVERSAFE RUBBER BERHAD', '0190')
# ('EVERSENDAI CORPORATION BERHAD', '5205')
# ('EWEIN BERHAD', '7249')
# ('EXCEL FORCE MSC BERHAD', '0065')
# ('FACB INDUSTRIES INCORPORATED BERHAD', '2984')
# ('FAJARBARU BUILDER GROUP BHD', '7047')
# ('FAR EAST HOLDINGS BERHAD', '5029')
# ('FARLIM GROUP (MALAYSIA) BHD', '6041')
# ('FARM FRESH BERHAD', '5306')
# ('FAST ENERGY HOLDINGS BERHAD', '0084')
# ('FAVELLE FAVCO BERHAD', '7229')
# ('FCW HOLDINGS BERHAD', '2755')
# ('FEDERAL INTERNATIONAL HOLDINGS BERHAD', '8605')
# ('FGV HOLDINGS BERHAD', '5222')
# ('FIAMMA HOLDINGS BERHAD', '6939')
# ('FIBON BERHAD', '0149')
# ('FIBROMAT (M) BERHAD', '03026')
# ('FIMA CORPORATION BERHAD', '3107')
# ('FINTEC GLOBAL BERHAD', '0150')
# ('FITTERS DIVERSIFIED BERHAD', '9318')
# ('FLEXIDYNAMIC HOLDINGS BERHAD', '0231')
# ('FM GLOBAL LOGISTICS HOLDINGS BERHAD', '7210')
# ('FOCUS DYNAMICS GROUP BERHAD', '0116')
# ('FOCUS LUMBER BERHAD', '5197')
# ('FOCUS POINT HOLDINGS BERHAD', '0157')
# ('FORMOSA PROSONIC INDUSTRIES BERHAD', '9172')
# ('FOUNDPAC GROUP BERHAD', '5277')
# ('FRASER & NEAVE HOLDINGS BHD', '3689')
# ('FRONTKEN CORPORATION BERHAD', '0128')
# ('FSBM HOLDINGS BERHAD', '9377')
# ('FTSE BURSA MALAYSIA KLCI ETF', '0820EA')
# ('G CAPITAL BERHAD', '7676')
# ('G NEPTUNE BERHAD', '0045')
# ('G3 GLOBAL BERHAD', '7184')
# ('GABUNGAN AQRS BERHAD', '5226')
# ('GADANG HOLDINGS BHD', '9261')
# ('GAGASAN NADI CERGAS BERHAD', '0206')
# ('GAMUDA BERHAD', '5398')
# ('GAS MALAYSIA BERHAD', '5209')
# ('GDB HOLDINGS BERHAD', '0198')
# ('GDEX BERHAD', '0078')
# ('GENETEC TECHNOLOGY BERHAD', '0104')
# ('GENTING BERHAD', '3182')
# ('GENTING MALAYSIA BERHAD', '4715')
# ('GENTING PLANTATIONS BERHAD', '2291')
# ('GEORGE KENT (MALAYSIA) BERHAD', '3204')
# ('GE-SHEN CORPORATION BERHAD', '7197')
# ('GETS GLOBAL BERHAD', '5079')
# ('GFM SERVICES BERHAD', '0039')
# ('GHL SYSTEMS BERHAD', '0021')
# ('GIIB HOLDINGS BERHAD', '7192')
# ('GLOBAL ORIENTAL BERHAD', '1147')
# ('GLOBALTEC FORMATION BERHAD', '5220')
# ('GLOBETRONICS TECHNOLOGY BERHAD', '7022')
# ('GLOMAC BERHAD', '5020')
# ('GOLDEN LAND BERHAD', '7382')
# ('GOLDEN PHAROS BERHAD', '5649')
# ('GOPENG BERHAD', '2135')
# ('GPP RESOURCES BERHAD', '03029')
# ('GRAND CENTRAL ENTERPRISES BHD', '5592')
# ('GREATECH TECHNOLOGY BERHAD', '0208')
# ('GREEN OCEAN CORPORATION BERHAD', '0074')
# ('GREEN PACKET BERHAD', '0082')
# ('GREENYIELD BERHAD', '0136')
# ('GROMUTUAL BERHAD', '9962')
# ('GUAN CHONG BERHAD', '5102')
# ('GUH HOLDINGS BERHAD', '3247')
# ('GUOCOLAND (MALAYSIA) BERHAD', '1503')
# ('HAILY GROUP BERHAD', '0237')
# ('HANDAL ENERGY BERHAD', '7253')
# ('HAP SENG CONSOLIDATED BERHAD', '3034')
# ('HAP SENG PLANTATIONS HOLDINGS BERHAD', '5138')
# ('HARBOUR-LINK GROUP BERHAD', '2062')
# ('HARN LEN CORPORATION BHD', '7501')
# ('HARRISONS HOLDINGS (MALAYSIA) BERHAD', '5008')
# ('HARTALEGA HOLDINGS BERHAD', '5168')
# ('HB GLOBAL LIMITED', '5187')
# ('HCK CAPITAL GROUP BERHAD', '7105')
# ('HEINEKEN MALAYSIA BERHAD', '3255')
# ('HEITECH PADU BERHAD', '5028')
# ('HEKTAR REAL ESTATE INVESTMENT TRUST', '5121')
# ('HENG HUAT RESOURCES GROUP BERHAD', '0175')
# ('HENGYUAN REFINING COMPANY BERHAD', '4324')
# ('HEVEABOARD BERHAD', '5095')
# ('HEXTAR GLOBAL BERHAD', '5151')
# ('HEXTAR INDUSTRIES BERHAD', '0161')
# ('HEXZA CORPORATION BERHAD', '3298')
# ('HIAP HUAT HOLDINGS BERHAD', '0160')
# ('HIAP TECK VENTURE BERHAD', '5072')
# ('HIBISCUS PETROLEUM BERHAD', '5199')
# ('HIL INDUSTRIES BERHAD', '8443')
# ('HLT GLOBAL BERHAD', '0188')
# ('HO HUP CONSTRUCTION COMPANY BHD', '5169')
# ('HO WAH GENTING BERHAD', '9601')
# ('HOMERITZ CORPORATION BERHAD', '5160')
# ('HONG LEONG BANK BERHAD', '5819')
# ('HONG LEONG CAPITAL BERHAD', '5274')
# ('HONG LEONG FINANCIAL GROUP BERHAD', '1082')
# ('HONG LEONG INDUSTRIES BERHAD', '3301')
# ('HONG SENG CONSOLIDATED BERHAD', '0041')
# ('HPMT HOLDINGS BERHAD', '5291')
# ('HPP HOLDINGS BERHAD', '0228')
# ('HSS ENGINEERS BERHAD', '0185')
# ('HUA YANG BERHAD', '5062')
# ('HUBLINE BERHAD', '7013')
# ('HUME CEMENT INDUSTRIES BERHAD', '5000')
# ('HUP SENG INDUSTRIES BERHAD', '5024')
# ('HWA TAI INDUSTRIES BERHAD', '8478')
# ('I-BERHAD', '4251')
# ('IBRACO BERHAD', '5084')
# ('ICAPITAL.BIZ BERHAD', '5108')
# ('ICON OFFSHORE BERHAD', '5255')
# ('ICONIC WORLDWIDE BERHAD', '9113')
# ('ICT ZONE ASIA BERHAD', '03038')
# ('IDB TECHNOLOGIES BERHAD', '03030')
# ('IDEAL UNITED BINTANG INTERNATIONAL BERHAD', '9687')
# ('IDIMENSION CONSOLIDATED BHD', '0174')
# ('IFCA MSC BERHAD', '0023')
# ('IGB BERHAD', '5606')
# ('IGB COMMERCIAL REAL ESTATE INVESTMENT TRUST', '5299')
# ('IGB REAL ESTATE INVESTMENT TRUST', '5227')
# ('IHH HEALTHCARE BERHAD', '5225')
# ('IJM CORPORATION BERHAD', '3336')
# ('IMASPRO CORPORATION BERHAD', '7222')
# ('IMPIANA HOTELS BERHAD', '7243')
# ('INARI AMERTRON BERHAD', '0166')
# ('INCH KENNETH KAJANG RUBBER PUBLIC LTD CO', '2607')
# ('INDUSTRONICS BERHAD', '9393')
# ('INNATURE BERHAD', '5295')
# ('INNITY CORPORATION BERHAD', '0147')
# ('INNOPRISE PLANTATIONS BERHAD', '6262')
# ('INSAS BERHAD', '3379')
# ('INTA BINA GROUP BERHAD', '0192')
# ('INTEGRATED LOGISTICS BHD', '5614')
# ('IOI CORPORATION BERHAD', '1961')
# ('IOI PROPERTIES GROUP BERHAD', '5249')
# ('IQ GROUP HOLDINGS BERHAD', '5107')
# ('IQZAN HOLDING BERHAD', '7183')
# ('IREKA CORPORATION BERHAD', '8834')
# ('IRIS CORPORATION BERHAD', '0010')
# ('ISKANDAR WATERFRONT CITY BERHAD', '1589')
# ('IVORY PROPERTIES GROUP BERHAD', '5175')
# ('JADE MARVEL GROUP BERHAD', '7043')
# ('JADI IMAGING HOLDINGS BERHAD', '7223')
# ('JAG BERHAD', '0024')
# ('JAKS RESOURCES BERHAD', '4723')
# ('JASA KITA BERHAD', '8648')
# ('JAYA TIASA HOLDINGS BHD', '4383')
# ('JAYCORP BERHAD', '7152')
# ('JCBNEXT BERHAD', '0058')
# ('JCY INTERNATIONAL BERHAD', '5161')
# ('JENTAYU SUSTAINABLES BERHAD', '5673')
# ('JERASIA CAPITAL BERHAD', '8931')
# ('JF TECHNOLOGY BERHAD', '0146')
# ('JHM CONSOLIDATION BERHAD', '0127')
# ('JIANKUN INTERNATIONAL BERHAD', '8923')
# ('JISHAN BERHAD', '03040')
# ('JKG LAND BERHAD', '6769')
# ('JOE HOLDING BERHAD', '7096')
# ('JOHAN HOLDINGS BERHAD', '3441')
# ('K. SENG SENG CORPORATION BERHAD', '5192')
# ('KAMDAR GROUP (M) BERHAD', '8672')
# ('KANGER INTERNATIONAL BERHAD', '0170')
# ('KAREX BERHAD', '5247')
# ('KARYON INDUSTRIES BERHAD', '0054')
# ('KAWAN FOOD BERHAD', '7216')
# ('KECK SENG (MALAYSIA) BERHAD', '3476')
# ('KEIN HING INTERNATIONAL BERHAD', '7199')
# ('KEJURUTERAAN ASASTERA BERHAD', '0193')
# ('KELINGTON GROUP BERHAD', '0151')
# ('KEN HOLDINGS BERHAD', '7323')
# ('KENANGA INVESTMENT BANK BERHAD', '6483')
# ('KENANGA KLCI DAILY (-1X) INVERSE ETF', '0835EA')
# ('KENANGA KLCI DAILY 2X LEVERAGED ETF', '0834EA')
# ('KERJAYA PROSPEK GROUP BERHAD', '7161')
# ('KERJAYA PROSPEK PROPERTY BERHAD', '7077')
# ('KESM INDUSTRIES BERHAD', '9334')
# ('KEY ALLIANCE GROUP BERHAD', '0036')
# ('KEY ASIC BERHAD', '0143')
# ('KHEE SAN BERHAD', '6203')
# ('KHIND HOLDINGS BERHAD', '7062')
# ('KIA LIM BERHAD', '6211')
# ('KIM HIN INDUSTRY BERHAD', '5371')
# ('KIM HIN JOO (MALAYSIA) BERHAD', '0210')
# ('KIM LOONG RESOURCES BERHAD', '5027')
# ('KIM TECK CHEONG CONSOLIDATED BERHAD', '0180')
# ('KIMLUN CORPORATION BERHAD', '5171')
# ('KIP REAL ESTATE INVESTMENT TRUST', '5280')
# ('KKB ENGINEERING BERHAD', '9466')
# ('KLCC PROPERTY HOLDINGS BERHAD', '5235SS')
# ('KLUANG RUBBER COMPANY (MALAYA) BERHAD', '2453')
# ('KNM GROUP BERHAD', '7164')
# ('KNUSFORD BERHAD', '5035')
# ('KOBAY TECHNOLOGY BERHAD', '6971')
# ('KOMARKCORP BERHAD', '7017')
# ('K-ONE TECHNOLOGY BERHAD', '0111')
# ('KONSORTIUM TRANSNASIONAL BERHAD', '4847')
# ('KOSSAN RUBBER INDUSTRIES BERHAD', '7153')
# ('KOTRA INDUSTRIES BERHAD', '0002')
# ('KPJ HEALTHCARE BERHAD', '5878')
# ('KPOWER BERHAD', '7130')
# ('KPS CONSORTIUM BERHAD', '9121')
# ('KRETAM HOLDINGS BERHAD', '1996')
# ('KRONOLOGI ASIA BERHAD', '0176')
# ('KSL HOLDINGS BERHAD', '5038')
# ('KUALA LUMPUR KEPONG BERHAD', '2445')
# ('KUB MALAYSIA BERHAD', '6874')
# ('KUCHAI DEVELOPMENT BERHAD', '2186')
# ('KUMPULAN FIMA BERHAD', '6491')
# ('KUMPULAN H & L HIGH-TECH BERHAD', '7033')
# ('KUMPULAN JETSON BERHAD', '9083')
# ('KUMPULAN PERANGSANG SELANGOR BERHAD', '5843')
# ('KYM HOLDINGS BERHAD', '8362')
# ('LAGENDA PROPERTIES BERHAD', '7179')
# ('LAMBO GROUP BERHAD', '0018')
# ('LAND & GENERAL BERHAD', '3174')
# ('LANDMARKS BERHAD', '1643')
# ('LAY HONG BERHAD', '9385')
# ('LB ALUMINIUM BERHAD', '9326')
# ('LBI CAPITAL BERHAD', '8494')
# ('LBS BINA GROUP BERHAD', '5789')
# ('LEADER STEEL HOLDINGS BERHAD', '9881')
# ('LEBTECH BERHAD', '9628')
# ('LEE SWEE KIAT GROUP BERHAD', '8079')
# ('LEON FUAT BERHAD', '5232')
# ('LEONG HUP INTERNATIONAL BERHAD', '6633')
# ('LFE CORPORATION BERHAD', '7170')
# ('LGMS BERHAD', '0249')
# ('LIEN HOE CORPORATION BERHAD', '3573')
# ('LII HEN INDUSTRIES BHD.', '7089')
# ('LIM SEONG HAI CAPITAL BERHAD', '03047')
# ('LINGKARAN TRANS KOTA HOLDINGS BERHAD', '6645')
# ('LION INDUSTRIES CORPORATION BERHAD', '4235')
# ('LION POSIM BERHAD', '8486')
# ('LKL INTERNATIONAL BERHAD', '0182')
# ('LOTTE CHEMICAL TITAN HOLDING BERHAD', '5284')
# ('LOTUS KFM BERHAD', '8303')
# ('LPI CAPITAL BHD', '8621')
# ('LTKM BERHAD', '7085')
# ('LUSTER INDUSTRIES BHD.', '5068')
# ('LUXCHEM CORPORATION BERHAD', '5143')
# ('LYC HEALTHCARE BERHAD', '0075')
# ('LYSAGHT GALVANIZED STEEL BERHAD', '9199')
# ('M N C WIRELESS BERHAD', '0103')
# ('MAA GROUP BERHAD', '1198')
# ('MAG HOLDINGS BERHAD', '0095')
# ('MAGNA PRIMA BERHAD', '7617')
# ('MAGNI-TECH INDUSTRIES BERHAD', '7087')
# ('MAGNUM BERHAD', '3859')
# ('MAH SING GROUP BERHAD', '8583')
# ('MAJUPERAK HOLDINGS BERHAD', '8141')
# ('MALAKOFF CORPORATION BERHAD', '5264')
# ('MALAYAN BANKING BERHAD', '1155')
# ('MALAYAN CEMENT BERHAD', '3794')
# ('MALAYAN FLOUR MILLS BERHAD', '3662')
# ('MALAYAN UNITED INDUSTRIES BERHAD', '3891')
# ('MALAYSIA AIRPORTS HOLDINGS BERHAD', '5014')
# ('MALAYSIA BUILDING SOCIETY BERHAD', '1171')
# ('MALAYSIA MARINE AND HEAVY ENGINEERING HOLDINGS BERHAD', '5186')
# ('MALAYSIA SMELTING CORPORATION BERHAD', '5916')
# ('MALAYSIA STEEL WORKS (KL) BHD', '5098')
# ('MALAYSIAN BULK CARRIERS BERHAD', '5077')
# ('MALAYSIAN GENOMICS RESOURCE CENTRE BERHAD', '0155')
# ('MALAYSIAN PACIFIC INDUSTRIES BERHAD', '3867')
# ('MALAYSIAN RESOURCES CORPORATION BERHAD', '1651')
# ('MALPAC HOLDINGS BERHAD', '4936')
# ('MALTON BERHAD', '6181')
# ('MANAGEPAY SYSTEMS BERHAD', '0156')
# ('MANFORCE GROUP BERHAD', '03015')
# ('MANULIFE HOLDINGS BERHAD', '1058')
# ('MARCO HOLDINGS BERHAD', '3514')
# ('MARINE & GENERAL BERHAD', '5078')
# ('MASTER-PACK GROUP BERHAD', '7029')
# ('MATANG BERHAD', '0189')
# ('MATRIX CONCEPTS HOLDINGS BERHAD', '5236')
# ('MATRIX PARKING SOLUTION HOLDINGS BERHAD', '03019')
# ('MAXIM GLOBAL BERHAD', '4022')
# ('MAXIS BERHAD', '6012')
# ('MBM RESOURCES BHD', '5983')
# ('MCE HOLDINGS BERHAD', '7004')
# ('MCLEAN TECHNOLOGIES BERHAD', '0167')
# ('MCOM HOLDINGS BERHAD', '03022')
# ('MCT BERHAD', '5182')
# ('MEDIA CHINESE INTERNATIONAL LIMITED', '5090')
# ('MEDIA PRIMA BERHAD', '4502')
# ('MEGA FIRST CORPORATION BERHAD', '3069')
# ('MEGA SUN CITY HOLDINGS BERHAD', '0081')
# ('MELATI EHSAN HOLDINGS BERHAD', '5129')
# ('MELEWAR INDUSTRIAL GROUP BERHAD', '3778')
# ('MENANG CORPORATION (M) BERHAD', '1694')
# ('MENTIGA CORPORATION BERHAD', '5223')
# ('MERCURY INDUSTRIES BERHAD', '8192')
# ('MERIDIAN BERHAD', '5040')
# ('MESB BERHAD', '7234')
# ('MESINIAGA BERHAD', '5011')
# ('MESTRON HOLDINGS BERHAD', '0207')
# ('METRO HEALTHCARE BERHAD', '03005')
# ('METROD HOLDINGS BERHAD', '6149')
# ('METRONIC GLOBAL BERHAD', '0043')
# ('MGB BERHAD', '7595')
# ('MHC PLANTATIONS BHD', '5026')
# ('MI TECHNOVATION BERHAD', '5286')
# ('MICROLINK SOLUTIONS BERHAD', '0126')
# ('MIECO CHIPBOARD BERHAD', '5001')
# ('MIKRO MSC BERHAD', '0112')
# ('MILUX CORPORATION BERHAD', '7935')
# ('MINDA GLOBAL BERHAD', '5166')
# ('MINETECH RESOURCES BERHAD', '7219')
# ('MINHO (M) BERHAD', '5576')
# ('MISC BERHAD', '3816')
# ('MITRAJAYA HOLDINGS BERHAD', '9571')
# ('MK LAND HOLDINGS BERHAD', '8893')
# ('MKH BERHAD', '6114')
# ('MLABS SYSTEMS BERHAD', '0085')
# ('MMAG HOLDINGS BERHAD', '0034')
# ('MMIS BERHAD', '03027')
# ('MMS VENTURES BERHAD', '0113')
# ('MN HOLDINGS BERHAD', '0245')
# ('MNRB HOLDINGS BERHAD', '6459')
# ('MOBILIA HOLDINGS BERHAD', '0229')
# ('MPHB CAPITAL BERHAD', '5237')
# ('MQ TECHNOLOGY BERHAD', '0070')
# ('MR D.I.Y. GROUP (M) BERHAD', '5296')
# ('MSM MALAYSIA HOLDINGS BERHAD', '5202')
# ('MTAG GROUP BERHAD', '0213')
# ('MTOUCHE TECHNOLOGY BERHAD', '0092')
# ('MUAR BAN LEE GROUP BERHAD', '5152')
# ('MUDA HOLDINGS BERHAD', '3883')
# ('MUDAJAYA GROUP BERHAD', '5085')
# ('MUHIBBAH ENGINEERING (M) BHD', '5703')
# ('MUI PROPERTIES BERHAD', '3913')
# ('MULPHA INTERNATIONAL BERHAD', '3905')
# ('MULTI-USAGE HOLDINGS BERHAD', '9539')
# ('MY E.G. SERVICES BERHAD', '0138')
# ('MYCRON STEEL BERHAD', '5087')
# ('MYETF DOW JONES ISLAMIC MARKET MALAYSIA TITANS 25', '0821EA')
# ('MYETF DOW JONES U.S. TITANS 50', '0827EA')
# ('MYETF MSCI MALAYSIA ISLAMIC DIVIDEND', '0824EA')
# ('MYETF MSCI SEA ISLAMIC DIVIDEND', '0825EA')
# ('MYNEWS HOLDINGS BERHAD', '5275')
# ('MYTECH GROUP BERHAD', '7692')
# ('N2N CONNECT BERHAD', '0108')
# ('NAIM HOLDINGS BERHAD', '5073')
# ('NCT ALLIANCE BERHAD', '0056')
# ('NEGRI SEMBILAN OIL PALMS BERHAD', '2038')
# ('NESTCON BERHAD', '0235')
# ('NESTLE (MALAYSIA) BERHAD', '4707')
# ('NETX HOLDINGS BERHAD', '0020')
# ('NEW HOONG FATT HOLDINGS BERHAD', '7060')
# ('NEXGRAM HOLDINGS BERHAD', '0096')
# ('NEXTGREEN GLOBAL BERHAD', '7241')
# ('NI HSIN GROUP BERHAD', '7215')
# ('NICHE CAPITAL EMAS HOLDINGS BERHAD', '7139')
# ('NOTION VTEC BERHAD', '0083')
# ('NOVA MSC BERHAD', '0026')
# ('NOVA PHARMA SOLUTIONS BERHAD', '03006')
# ('NOVA WELLNESS GROUP BERHAD', '0201')
# ('NOVELPLUS TECHNOLOGY BERHAD', '03045')
# ('NPC RESOURCES BERHAD', '5047')
# ('NTPM HOLDINGS BERHAD', '5066')
# ('NWP HOLDINGS BERHAD', '5025')
# ('NYLEX (MALAYSIA) BERHAD', '4944')
# ('OCB BERHAD', '5533')
# ('OCEAN VANTAGE HOLDINGS BERHAD', '0220')
# ('OCEANCASH PACIFIC BERHAD', '0049')
# ('OCK GROUP BERHAD', '0172')
# ('OCR GROUP BERHAD', '7071')
# ('OKA CORPORATION BHD', '7140')
# ('OLYMPIA INDUSTRIES BERHAD', '3018')
# ('OM HOLDINGS LIMITED', '5298')
# ('OMESTI BERHAD', '9008')
# ('ONETECH SOLUTIONS HOLDINGS BERHAD', '03041')
# ('ONLY WORLD GROUP HOLDINGS BERHAD', '5260')
# ('OPCOM HOLDINGS BERHAD', '0035')
# ('OPENSYS (M) BERHAD', '0040')
# ('OPTIMAX HOLDINGS BERHAD', '0222')
# ('ORIENTAL FOOD INDUSTRIES HOLDINGS BERHAD', '7107')
# ('ORIENTAL HOLDINGS BERHAD', '4006')
# ('ORIENTAL INTEREST BERHAD', '5827')
# ('ORNAPAPER BERHAD', '5065')
# ('OSK HOLDINGS BERHAD', '5053')
# ('OSK VENTURES INTERNATIONAL BERHAD', '0053')
# ('OVERSEA ENTERPRISE BERHAD', '0153')
# ('P.A. RESOURCES BERHAD', '7225')
# ('P.I.E. INDUSTRIAL BERHAD', '7095')
# ('PACIFIC & ORIENT BERHAD', '6009')
# ('PADINI HOLDINGS BERHAD', '7052')
# ('PAN MALAYSIA CORPORATION BERHAD', '4081')
# ('PAN MALAYSIA HOLDINGS BERHAD', '1287')
# ('PANASONIC MANUFACTURING MALAYSIA BERHAD', '3719')
# ('PANSAR BERHAD', '8419')
# ('PANTECH GROUP HOLDINGS BERHAD', '5125')
# ('PAOS HOLDINGS BERHAD', '5022')
# ('PAPPAJACK BERHAD', '0242')
# ('PARAGON GLOBE BERHAD', '3611')
# ('PARAGON UNION BERHAD', '9407')
# ('PARAMOUNT CORPORATION BERHAD', '1724')
# ('PARKSON HOLDINGS BERHAD', '5657')
# ('PARKWOOD HOLDINGS BERHAD', '2682')
# ('PARLO BERHAD', '0022')
# ('PASDEC HOLDINGS BERHAD', '6912')
# ('PASUKHAS GROUP BERHAD', '0177')
# ('PAVILION REAL ESTATE INVESTMENT TRUST', '5212')
# ('PBA HOLDINGS BHD', '5041')
# ('PCCS GROUP BERHAD', '6068')
# ('PDZ HOLDINGS BHD', '6254')
# ('PECCA GROUP BERHAD', '5271')
# ('PEGASUS HEIGHTS BERHAD', '4464')
# ('PEKAT GROUP BERHAD', '0233')
# ('PELIKAN INTERNATIONAL CORPORATION BERHAD', '5231')
# ('PENSONIC HOLDINGS BERHAD', '9997')
# ('PENTAMASTER CORPORATION BERHAD', '7160')
# ('PERAK CORPORATION BERHAD', '8346')
# ('PERAK TRANSIT BERHAD', '0186')
# ('PERDANA PETROLEUM BERHAD', '7108')
# ('PERMAJU INDUSTRIES BERHAD', '7080')
# ('PERTAMA DIGITAL BERHAD', '8532')
# ('PERUSAHAAN SADUR TIMAH MALAYSIA (PERSTIMA) BHD', '5436')
# ('PESONA METRO HOLDINGS BERHAD', '8311')
# ('PESTECH INTERNATIONAL BERHAD', '5219')
# ('PETERLABS HOLDINGS BERHAD', '0171')
# ('PETRA ENERGY BERHAD', '5133')
# ('PETRON MALAYSIA REFINING & MARKETING BHD', '3042')
# ('PETRONAS CHEMICALS GROUP BERHAD', '5183')
# ('PETRONAS DAGANGAN BHD', '5681')
# ('PETRONAS GAS BERHAD', '6033')
# ('PGF CAPITAL BERHAD', '8117')
# ('PHARMANIAGA BERHAD', '7081')
# ('PIMPINAN EHSAN BERHAD', '5622')
# ('PINEAPPLE RESOURCES BERHAD', '0006')
# ('PINEHILL PACIFIC BERHAD', '1902')
# ('PINTARAS JAYA BHD', '9598')
# ('PJBUMI BERHAD', '7163')
# ('PLB ENGINEERING BERHAD', '7055')
# ('PLENITUDE BERHAD', '5075')
# ('PLS PLANTATIONS BERHAD', '9695')
# ('PMB TECHNOLOGY BERHAD', '7172')
# ('PNE PCB BERHAD', '6637')
# ('POH HUAT RESOURCES HOLDINGS BERHAD', '7088')
# ('POH KONG HOLDINGS BERHAD', '5080')
# ('POLYDAMIC GROUP BERHAD', '03031')
# ('POS MALAYSIA BERHAD', '4634')
# ('POWER ROOT BERHAD', '7237')
# ('POWERWELL HOLDINGS BERHAD', '0217')
# ('PPB GROUP BERHAD', '4065')
# ('PRESS METAL ALUMINIUM HOLDINGS BERHAD', '8869')
# ('PRESTAR RESOURCES BERHAD', '9873')
# ('PRG HOLDINGS BERHAD', '7168')
# ('PRICEWORTH INTERNATIONAL BERHAD', '7123')
# ('PRINCIPAL FTSE ASEAN 40 MALAYSIA ETF', '0822EA')
# ('PRINCIPAL FTSE CHINA 50 ETF', '0823EA')
# ('PRIVASIA TECHNOLOGY BERHAD', '0123')
# ('PROGRESSIVE IMPACT CORPORATION BERHAD', '7201')
# ('PROLEXUS BERHAD', '8966')
# ('PROPEL GLOBAL BERHAD', '0091')
# ('PROTASCO BERHAD', '5070')
# ('PTT SYNERGY GROUP BERHAD', '7010')
# ('PUBLIC BANK BERHAD', '1295')
# ('PUBLIC PACKAGES HOLDINGS BHD', '8273')
# ('PUC BERHAD', '0007')
# ('PUNCAK NIAGA HOLDINGS BERHAD', '6807')
# ('PWF CORPORATION BERHAD', '7134')
# ('QES GROUP BERHAD', '0196')
# ('QL RESOURCES BERHAD', '7084')
# ('QUALITY CONCRETE HOLDINGS BERHAD', '7544')
# ('RADIANT GLOBALTECH BERHAD', '0202')
# ('RALCO CORPORATION BERHAD', '7498')
# ('RAMSSOL GROUP BERHAD', '0236')
# ('RANHILL UTILITIES BERHAD', '5272')
# ('RAPID SYNERGY BERHAD', '7765')
# ('RAY GO SOLAR HOLDINGS BERHAD', '03052')
# ('RCE CAPITAL BERHAD', '9296')
# ('REACH ENERGY BERHAD', '5256')
# ('RED IDEAS HOLDINGS BERHAD', '03002')
# ('RED SENA BERHAD', '5270')
# ('REDPLANET BERHAD', '03036')
# ('REDTONE DIGITAL BERHAD', '0032')
# ('RESERVOIR LINK ENERGY BHD', '0219')
# ('RESINTECH BERHAD', '7232')
# ('REVENUE GROUP BERHAD', '0200')
# ('REX INDUSTRY BERHAD', '9946')
# ('REXIT BERHAD', '0106')
# ('RGB INTERNATIONAL BHD', '0037')
# ('RGT BERHAD', '9954')
# ('RHB BANK BERHAD', '1066')
# ('RHONE MA HOLDINGS BERHAD', '5278')
# ('RHONG KHEN INTERNATIONAL BERHAD', '7006')
# ('RIMBUNAN SAWIT BERHAD', '5113')
# ('RIVERVIEW RUBBER ESTATES BERHAD', '2542')
# ('ROHAS TECNIC BERHAD', '9741')
# ('RTS TECHNOLOGY HOLDINGS BERHAD', '03039')
# ('RUBBEREX CORPORATION (M) BERHAD', '7803')
# ('S & F CAPITAL BERHAD', '8745')
# ('S P SETIA BERHAD', '8664')
# ('SALCON BERHAD', '8567')
# ('SALUTICA BERHAD', '0183')
# ('SAM ENGINEERING & EQUIPMENT (M) BERHAD', '9822')
# ('SAMAIDEN GROUP BERHAD', '0223')
# ('SAMCHEM HOLDINGS BERHAD', '5147')
# ('SAND NISKO CAPITAL BERHAD', '7943')
# ('SANICHI TECHNOLOGY BERHAD', '0133')
# ('SAPURA ENERGY BERHAD', '5218')
# ('SAPURA INDUSTRIAL BERHAD', '7811')
# ('SAPURA RESOURCES BERHAD', '4596')
# ('SARAWAK CABLE BERHAD', '5170')
# ('SARAWAK CONSOLIDATED INDUSTRIES BERHAD', '9237')
# ('SARAWAK OIL PALMS BERHAD', '5126')
# ('SARAWAK PLANTATION BERHAD', '5135')
# ('SASBADI HOLDINGS BERHAD', '5252')
# ('SAUDEE GROUP BERHAD', '5157')
# ('SBC CORPORATION BERHAD', '5207')
# ('SC ESTATE BUILDER BERHAD', '0109')
# ('SCANWOLF CORPORATION BERHAD', '7239')
# ('SCC HOLDINGS BERHAD', '0158')
# ('SCGM BHD', '7247')
# ('SCICOM (MSC) BERHAD', '0099')
# ('SCIENTEX BERHAD', '4731')
# ('SCIENTEX PACKAGING (AYER KEROH) BERHAD', '8125')
# ('SCOMI ENERGY SERVICES BHD', '7045')
# ('SCOMI GROUP BERHAD', '7158')
# ('SCOPE INDUSTRIES BERHAD', '0028')
# ('SDS GROUP BERHAD', '0212')
# ('SEACERA GROUP BERHAD', '7073')
# ('SEAL INCORPORATED BERHAD', '4286')
# ('SEALINK INTERNATIONAL BERHAD', '5145')
# ('SECUREMETRIC BERHAD', '0203')
# ('SEDANIA INNOVATOR BERHAD', '0178')
# ('SEE HUP CONSOLIDATED BERHAD', '7053')
# ('SEG INTERNATIONAL BHD', '9792')
# ('SELANGOR DREDGING BERHAD', '2224')
# ('SENHENG NEW RETAIL BERHAD', '5305')
# ('SENI JAYA CORPORATION BERHAD', '9431')
# ('SENTORIA GROUP BERHAD', '5213')
# ('SENTRAL REIT', '5123')
# ('SERBA DINAMIK HOLDINGS BERHAD', '5279')
# ('SEREMBAN ENGINEERING BERHAD', '5163')
# ('SERN KOU RESOURCES BERHAD', '7180')
# ('SERSOL BERHAD', '0055')
# ('SFP TECH HOLDINGS BERHAD', '0251')
# ('SHANGRI-LA HOTELS (MALAYSIA) BERHAD', '5517')
# ('SHH RESOURCES HOLDINGS BERHAD', '7412')
# ('SHIN YANG SHIPPING CORPORATION BERHAD', '5173')
# ('SHL CONSOLIDATED BHD', '6017')
# ('SIAB HOLDINGS BERHAD', '0241')
# ('SIGNATURE INTERNATIONAL BERHAD', '7246')
# ('SILVER RIDGE HOLDINGS BHD', '0129')
# ('SIME DARBY BERHAD', '4197')
# ('SIME DARBY PLANTATION BERHAD', '5285')
# ('SIME DARBY PROPERTY BERHAD', '5288')
# ('SIN HENG CHAN (MALAYA) BERHAD', '4316')
# ('SINARAN ADVANCE GROUP BERHAD', '5172')
# ('SINMAH CAPITAL BERHAD', '9776')
# ('SKB SHUTTERS CORPORATION BERHAD', '7115')
# ('SKP RESOURCES BHD', '7155')
# ('SL INNOVATION CAPITAL BERHAD', '03008')
# ('SLP RESOURCES BERHAD', '7248')
# ('SMILE-LINK HEALTHCARE GLOBAL BERHAD', '03023')
# ('SMIS CORPORATION BERHAD', '7132')
# ('SMRT HOLDINGS BERHAD', '0117')
# ('SMTRACK BERHAD', '0169')
# ('SNOWFIT GROUP BERHAD', '03054')
# ('SOLARVEST HOLDINGS BERHAD', '0215')
# ('SOLID AUTOMOTIVE BERHAD', '5242')
# ('SOLUTION GROUP BERHAD', '0093')
# ('SOUTH MALAYSIA INDUSTRIES BERHAD', '4375')
# ('SOUTHERN ACIDS (M) BERHAD', '5134')
# ('SOUTHERN CABLE GROUP BERHAD', '0225')
# ('SOUTHERN STEEL BERHAD', '5665')
# ('SPORTS TOTO BERHAD', '1562')
# ('SPRING ART HOLDINGS BERHAD', '0216')
# ('SPRITZER BHD', '7103')
# ('STAR MEDIA GROUP BERHAD', '6084')
# ('STEEL HAWK BERHAD', '03049')
# ('STELLA HOLDINGS BERHAD', '5006')
# ('STRAITS ENERGY RESOURCES BERHAD', '0080')
# ('SUBUR TIASA HOLDINGS BERHAD', '6904')
# ('SUCCESS TRANSFORMER CORPORATION BERHAD', '7207')
# ('SUNGEI BAGAN RUBBER COMPANY (MALAYA) BERHAD', '2569')
# ('SUNMOW HOLDING BERHAD', '03050')
# ('SUNSURIA BERHAD', '3743')
# ('SUNWAY BERHAD', '5211')
# ('SUNWAY CONSTRUCTION GROUP BERHAD', '5263')
# ('SUNWAY REAL ESTATE INVESTMENT TRUST', '5176')
# ('SUNZEN BIOTECH BERHAD', '0148')
# ('SUPERCOMNET TECHNOLOGIES BERHAD', '0001')
# ('SUPERGENICS BERHAD', '03033')
# ('SUPERLON HOLDINGS BERHAD', '7235')
# ('SUPERMAX CORPORATION BERHAD', '7106')
# ('SUPREME CONSOLIDATED RESOURCES BERHAD', '03018')
# ('SURIA CAPITAL HOLDINGS BERHAD', '6521')
# ('SWIFT HAULAGE BERHAD', '5303')
# ('SWS CAPITAL BERHAD', '7186')
# ('SYARIKAT TAKAFUL MALAYSIA KELUARGA BERHAD', '6139')
# ('SYCAL VENTURES BERHAD', '9717')
# ('SYF RESOURCES BERHAD', '7082')
# ('SYMPHONY LIFE BERHAD', '1538')
# ('SYSTECH BHD', '0050')
# ('T7 GLOBAL BERHAD', '7228')
# ('TA ANN HOLDINGS BERHAD', '5012')
# ('TA WIN HOLDINGS BERHAD', '7097')
# ('TAFI INDUSTRIES BERHAD', '7211')
# ('TALAM TRANSFORM BERHAD', '2259')
# ('TALIWORKS CORPORATION BERHAD', '8524')
# ('TAMBUN INDAH LAND BERHAD', '5191')
# ('TAN CHONG MOTOR HOLDINGS BERHAD', '4405')
# ('TANCO HOLDINGS BERHAD', '2429')
# ('TAS OFFSHORE BERHAD', '5149')
# ('TASCO BERHAD', '5140')
# ('TASHIN HOLDINGS BERHAD', '0211')
# ('TCS GROUP HOLDINGS BERHAD', '0221')
# ('TDM BERHAD', '2054')
# ('TECHBOND GROUP BERHAD', '5289')
# ('TECHNA-X BERHAD', '2739')
# ('TECHNODEX BHD', '0132')
# ('TECK GUAN PERDANA BERHAD', '7439')
# ('TEK SENG HOLDINGS BERHAD', '7200')
# ('TELADAN SETIA GROUP BERHAD', '0230')
# ('TELEKOM MALAYSIA BERHAD', '4863')
# ('TENAGA NASIONAL BHD', '5347')
# ('TEO GUAN LEE CORPORATION BERHAD', '9369')
# ('TEO SENG CAPITAL BERHAD', '7252')
# ('TEX CYCLE TECHNOLOGY (M) BERHAD', '0089')
# ('TEXCHEM RESOURCES BERHAD', '8702')
# ('TFP SOLUTIONS BERHAD', '0145')
# ('TH PLANTATIONS BERHAD', '5112')
# ('THETA EDGE BERHAD', '9075')
# ('THONG GUAN INDUSTRIES BERHAD', '7034')
# ('THREE-A RESOURCES BERHAD', '0012')
# ('THRIVEN GLOBAL BERHAD', '7889')
# ('TIEN WAH PRESS HOLDINGS BERHAD', '7374')
# ('TIMBERWELL BERHAD', '7854')
# ('TIME DOTCOM BERHAD', '5031')
# ('TIONG NAM LOGISTICS HOLDINGS BERHAD', '8397')
# ('TITIJAYA LAND BERHAD', '5239')
# ('TMC LIFE SCIENCES BERHAD', '0101')
# ('TOMEI CONSOLIDATED BERHAD', '7230')
# ('TOMYPAK HOLDINGS BERHAD', '7285')
# ('TONG HERR RESOURCES BERHAD', '5010')
# ('TOP BUILDERS CAPITAL BERHAD', '5268')
# ('TOP GLOVE CORPORATION BHD', '7113')
# ('TOPVISION EYE SPECIALIST BERHAD', '03013')
# ('TOWER REAL ESTATE INVESTMENT TRUST', '5111')
# ('TOYO VENTURES HOLDINGS BERHAD', '7173')
# ('TPC PLUS BERHAD', '7176')
# ('TRADEPLUS DWA MALAYSIA MOMENTUM TRACKER', '0836EA')
# ('TRADEPLUS HSCEI DAILY (-1X) INVERSE TRACKER', '0833EA')
# ('TRADEPLUS HSCEI DAILY (2X) LEVERAGED TRACKER', '0832EA')
# ('TRADEPLUS MSCI ASIA EX JAPAN REITS TRACKER', '0837EA')
# ('TRADEPLUS NYSE FANG+ DAILY (-1X) INVERSE TRACKER', '0831EA')
# ('TRADEPLUS NYSE FANG+ DAILY (2X) LEVERAGED TRACKER', '0830EA')
# ('TRADEPLUS S&P NEW CHINA TRACKER-MYR', '0829EA')
# ('TRADEPLUS S&P NEW CHINA TRACKER-USD', '0829EB')
# ('TRADEPLUS SHARIAH GOLD TRACKER', '0828EA')
# ('TRANSOCEAN HOLDINGS BHD', '7218')
# ('TRC SYNERGY BERHAD', '5054')
# ('TRI-MODE SYSTEM (M) BERHAD', '0199')
# ('TRIVE PROPERTY GROUP BERHAD', '0118')
# ('TROPICANA CORPORATION BERHAD', '5401')
# ('TSH RESOURCES BERHAD', '9059')
# ('TSR CAPITAL BERHAD', '5042')
# ('TUJU SETIA BERHAD', '5297')
# ('TUNE PROTECT GROUP BERHAD', '5230')
# ('TURBO-MECH BERHAD', '5167')
# ('TURIYA BERHAD', '4359')
# ('TWL HOLDINGS BERHAD', '7079')
# ('UCHI TECHNOLOGIES BERHAD', '7100')
# ('UCI RESOURCES BERHAD', '03043')
# ('UCREST BERHAD', '0005')
# ('UEM EDGENTA BERHAD', '1368')
# ('UEM SUNRISE BERHAD', '5148')
# ('UMS HOLDINGS BERHAD', '7137')
# ('UMS-NEIKEN GROUP BERHAD', '7227')
# ('UMW HOLDINGS BERHAD', '4588')
# ('UNI WALL APS HOLDINGS BERHAD', '03017')
# ('UNIMECH GROUP BERHAD', '7091')
# ('UNISEM (M) BERHAD', '5005')
# ('UNITED MALACCA BERHAD', '2593')
# ('UNITED PLANTATIONS BERHAD', '2089')
# ('UNITED U-LI CORPORATION BERHAD', '7133')
# ('UNITRADE INDUSTRIES BERHAD', '0247')
# ('UOA DEVELOPMENT BHD', '5200')
# ('UOA REAL ESTATE INVESTMENT TRUST', '5110')
# ('UPA CORPORATION BHD', '7757')
# ('UWC BERHAD', '5292')
# ('UZMA BERHAD', '7250')
# ('V.S. INDUSTRY BERHAD', '6963')
# ('VELESTO ENERGY BERHAD', '5243')
# ('VERSATILE CREATIVE BERHAD', '4995')
# ('VERTICE BERHAD', '7240')
# ('VINVEST CAPITAL HOLDINGS BERHAD', '0069')
# ('VISDYNAMICS HOLDINGS BERHAD', '0120')
# ('VITROX CORPORATION BERHAD', '0097')
# ('VIZIONE HOLDINGS BERHAD', '7070')
# ('VOLCANO BERHAD', '0232')
# ('VORTEX CONSOLIDATED BERHAD', '0060')
# ('VP-DJ SHARIAH CHINA A-SHARES 100 ETF - MYR', '0838EA')
# ('VSOLAR GROUP BERHAD', '0066')
# ('VSTECS BERHAD', '5162')
# ('WAH SEONG CORPORATION BERHAD', '5142')
# ('WAJA KONSORTIUM BERHAD', '0102')
# ('WANG-ZHENG BERHAD', '7203')
# ('WARISAN TC HOLDINGS BERHAD', '5016')
# ('WATTA HOLDING BERHAD', '7226')
# ('WCE HOLDINGS BERHAD', '3565')
# ('WCT HOLDINGS BERHAD', '9679')
# ('WEGMANS HOLDINGS BERHAD', '0197')
# ('WELLCALL HOLDINGS BERHAD', '7231')
# ('WESTPORTS HOLDINGS BERHAD', '5246')
# ('WHITE HORSE BERHAD', '5009')
# ('WIDAD GROUP BERHAD', '0162')
# ('WILLOWGLEN MSC BERHAD', '0008')
# ('WMG HOLDINGS BERHAD', '6378')
# ('WONG ENGINEERING CORPORATION BERHAD', '7050')
# ('WOODLANDOR HOLDINGS BHD', '7025')
# ('WTK HOLDINGS BERHAD', '4243')
# ('XIDELANG HOLDINGS LTD', '5156')
# ('XIN HWA HOLDINGS BERHAD', '5267')
# ('XL HOLDINGS BERHAD', '7121')
# ('XOX BHD', '0165')
# ('XOX NETWORKS BERHAD', '0140')
# ('XOX TECHNOLOGY BERHAD', '0017')
# ('Y&G CORPORATION BHD', '7003')
# ('Y.S.P.SOUTHEAST ASIA HOLDING BERHAD', '7178')
# ('YB VENTURES BERHAD', '5048')
# ('YBS INTERNATIONAL BERHAD', '0025')
# ('YENHER HOLDINGS BERHAD', '5300')
# ('YEW LEE PACIFIC GROUP BERHAD', '0248')
# ('YGL CONVERGENCE BERHAD', '0086')
# ('YINSON HOLDINGS BERHAD', '7293')
# ('YKGI HOLDINGS BERHAD', '7020')
# ('YLI HOLDINGS BERHAD', '7014')
# ('YNH PROPERTY BERHAD', '3158')
# ('YONG TAI BERHAD', '7066')
# ('YOONG ONN CORPORATION BERHAD', '5159')
# ('YTL CORPORATION BERHAD', '4677')
# ('YTL HOSPITALITY REIT', '5109')
# ('YTL POWER INTERNATIONAL BHD', '6742')
# ('YX PRECIOUS METALS BHD', '0250')
# ('ZECON BERHAD', '7028')
# ('ZELAN BERHAD', '2283')
# ('ZEN TECH INTERNATIONAL BERHAD', '0094')
# ('ZHULIAN CORPORATION BERHAD', '5131')

# %% [markdown]
# ### Add '.KL ' to use it for yahoo finance

# %%
df['stock_code']=df['stock_code']+'.KL'
# Out:
# C:\Users\Minyi\AppData\Local\Temp\ipykernel_27868\1639660786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['stock_code']=df['stock_code']+'.KL'

# %%
df = df.reset_index()

# %%
df
# Out:
#      index                         stock_name stock_code
# 0        0  7-ELEVEN MALAYSIA HOLDINGS BERHAD    5250.KL
# 1        1       ABF MALAYSIA BOND INDEX FUND  0800EA.KL
# 2        2                 ABLE GLOBAL BERHAD    7167.KL
# 3        3                   ABLEGROUP BERHAD    7086.KL
# 4        4                  ABM FUJIYA BERHAD    5198.KL
# ..     ...                                ...        ...
# 985    996             YX PRECIOUS METALS BHD    0250.KL
# 986    997                       ZECON BERHAD    7028.KL
# 987    998                       ZELAN BERHAD    2283.KL
# 988    999      ZEN TECH INTERNATIONAL BERHAD    0094.KL
# 989   1000         ZHULIAN CORPORATION BERHAD    5131.KL
#
# [990 rows x 3 columns]

# %%
del df['index']

# %%
df
# Out:
#                             stock_name stock_code
# 0    7-ELEVEN MALAYSIA HOLDINGS BERHAD    5250.KL
# 1         ABF MALAYSIA BOND INDEX FUND  0800EA.KL
# 2                   ABLE GLOBAL BERHAD    7167.KL
# 3                     ABLEGROUP BERHAD    7086.KL
# 4                    ABM FUJIYA BERHAD    5198.KL
# ..                                 ...        ...
# 985             YX PRECIOUS METALS BHD    0250.KL
# 986                       ZECON BERHAD    7028.KL
# 987                       ZELAN BERHAD    2283.KL
# 988      ZEN TECH INTERNATIONAL BERHAD    0094.KL
# 989         ZHULIAN CORPORATION BERHAD    5131.KL
#
# [990 rows x 2 columns]

# %%
# store the dataframe into a csv file for further uses
df.to_csv('stock_code.csv')
