# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from datetime import datetime
import pandas as pd
import time
import random
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.chrome.options import Options

# %%
df = pd.read_csv('div_info_final.csv')
df
# Out:
#       Unnamed: 0   Announced Financial Year                  Subject  \
# 0              0  2022-04-20     2021-12-31         Interim Dividend
# 1              1  2021-04-15     2020-12-31         Interim Dividend
# 2              2  2020-04-22     2019-12-31         Interim Dividend
# 3              3  2019-04-29     2018-12-31         Interim Dividend
# 4              4  2022-12-01     2022-12-31      Income Distribution
# ...          ...         ...            ...                      ...
# 4088        4088  2022-05-26     2022-06-30         Interim Dividend
# 4089        4089  2021-09-08     2021-06-30  Second Interim Dividend
# 4090        4090  2021-05-28     2021-06-30         Interim Dividend
# 4091        4091  2019-08-29     2019-06-30         Interim Dividend
# 4092        4092  2018-08-29     2018-06-30         Interim Dividend
#
#          EX Date Payment Date  Amount Indicator Stock Code  Year
# 0     2022-05-10   2022-05-27  0.0260  Currency       5250  2021
# 1     2021-05-05   2021-05-21  0.0160  Currency       5250  2020
# 2     2020-05-12   2020-05-28  0.0230  Currency       5250  2019
# 3     2019-05-09   2019-05-23  0.0240  Currency       5250  2018
# 4     2022-12-23   2023-01-12  0.0385  Currency     0800EA  2022
# ...          ...          ...     ...       ...        ...   ...
# 4088  2022-06-10   2022-06-29  0.0200  Currency       7028  2022
# 4089  2021-09-23   2021-10-12  0.0250  Currency       7028  2021
# 4090  2021-06-14   2021-06-29  0.0200  Currency       7028  2021
# 4091  2019-10-25   2019-11-13  0.0500  Currency       7028  2019
# 4092  2018-10-25   2018-11-13  0.0500  Currency       7028  2018
#
# [4093 rows x 10 columns]

# %%
stock_code = df['Stock Code'].unique()

# %%
len(stock_code)
# Out:
# 634

# %%
quarter_rep=pd.DataFrame()

driver = webdriver.Chrome()

#driver = webdriver.Chrome()
driver.implicitly_wait(604800)
new_list=[]

stock=['7148']
for s in stock_code:
    try:
        url='https://www.klsescreener.com/v2/stocks/view/'+s
        driver.get(url)
        p= driver.find_element(By.XPATH,'//*[@id="myTab"]/li[3]/a')
        driver.execute_script("arguments[0].click();",p)
        content = driver.page_source
        soup=bs(content)

        # scrap table

        tables = soup.find_all('table')
        # Step 3: Read tables with Pandas read_html()
        dfs = pd.read_html(str(tables))

        i = 0
        has_found = False
        while i < len(dfs) and not has_found:
            n = 0
            while n < len(dfs[i].columns):
                if dfs[i].columns[n] == 'ROE':
                    has_found = True
                n += 1
            i += 1
        if has_found:
            df=dfs[i-1]
            df2=df[['EPS','DPS','NTA','Revenue','P/L','Quarter','Q Date','Financial Year','Announced','ROE']]
            df2['Financial Year'] = pd.to_datetime(df['Financial Year'])
            df2['Financial Year']= pd.to_datetime(df2['Financial Year'].dt.strftime('%Y-%m-%d'))
            filtered_df = df2.loc[(df2['Financial Year'] >= '2018-01-01')
                          & (df2['Financial Year'] < '2023-12-31')]
            filtered_df.reset_index(drop=True, inplace=True)
            filtered_df.drop(filtered_df[filtered_df['EPS'] == filtered_df['Revenue']].index, inplace = True)
            filtered_df.reset_index(drop=True, inplace=True)
            filtered_df['Stock Code']=s
            filtered_df['Year'] = filtered_df['Financial Year'].dt.strftime("%Y")
            quarter_rep = quarter_rep.append(filtered_df, ignore_index=True)
            print("Stock code :"+s+" yes")
        else:
            print("Stock code :"+s+" has no  annual report")
    except:
        print("Stock code :"+s+" cannot scrap")
    # Program to generate a random number between 5 to 30
    # importing the random module
    sec = random.randint(3, 10)

    # program scrapping waiting time
    time.sleep(sec)  # Seconds
# Out:
# Stock code :5250 yes
# Stock code :0800EA yes
# Stock code :7167 yes
# Stock code :03028 yes
# Stock code :0218 yes
# Stock code :1481 yes
# Stock code :5281 yes
# Stock code :9148 yes
# Stock code :7191 yes
# Stock code :7146 yes
# Stock code :0181 yes
# Stock code :6599 yes
# Stock code :5139 yes
# Stock code :5185 yes
# Stock code :0209 yes
# Stock code :2658 yes
# Stock code :5116 yes
# Stock code :2674 yes
# Stock code :2488 yes
# Stock code :1163 yes
# Stock code :03051 yes
# Stock code :5269 yes
# Stock code :5127 yes
# Stock code :5293 yes
# Stock code :5120 yes
# Stock code :03011 yes
# Stock code :1015 yes
# Stock code :6351 yes
# Stock code :7083 yes
# Stock code :6556 yes
# Stock code :5568 yes
# Stock code :5088 yes
# Stock code :7090 yes
# Stock code :5015 yes
# Stock code :6432 yes
# Stock code :7214 yes
# Stock code :7722 yes
# Stock code :7129 yes
# Stock code :0105 yes
# Stock code :7162 yes
# Stock code :7048 yes
# Stock code :5130 yes
# Stock code :7099 yes
# Stock code :5204 yes
# Stock code :7579 yes
# Stock code :6888 yes
# Stock code :5106 yes
# Stock code :2305 yes
# Stock code :5021 yes
# Stock code :03012 yes
# Stock code :5258 yes
# Stock code :1899 yes
# Stock code :0187 yes
# Stock code :5196 yes
# Stock code :5248 yes
# Stock code :7668 yes
# Stock code :6173 yes
# Stock code :0195 yes
# Stock code :5032 yes
# Stock code :0179 yes
# Stock code :5069 yes
# Stock code :0168 yes
# Stock code :9288 yes
# Stock code :8133 yes
# Stock code :2771 yes
# Stock code :5254 yes
# Stock code :5100 yes
# Stock code :0011 yes
# Stock code :4162 yes
# Stock code :7221 yes
# Stock code :2828 yes
# Stock code :7174 yes
# Stock code :0191 yes
# Stock code :7154 yes
# Stock code :2852 yes
# Stock code :7128 yes
# Stock code :5105 yes
# Stock code :5099 yes
# Stock code :5180 yes
# Stock code :0163 yes
# Stock code :5257 yes
# Stock code :2836 yes
# Stock code :03048 yes
# Stock code :7076 yes
# Stock code :7035 yes
# Stock code :03024 yes
# Stock code :0238 yes
# Stock code :0243 yes
# Stock code :5195 yes
# Stock code :8982 yes
# Stock code :7209 yes
# Stock code :5273 yes
# Stock code :1929 yes
# Stock code :5007 yes
# Stock code :5797 yes
# Stock code :7016 yes
# Stock code :1023 yes
# Stock code :5104 yes
# Stock code :7117 yes
# Stock code :7202 yes
# Stock code :7195 yes
# Stock code :5136 yes
# Stock code :5049 yes
# Stock code :6718 yes
# Stock code :8591 yes
# Stock code :03016 yes
# Stock code :5094 yes
# Stock code :5301 yes
# Stock code :9423 yes
# Stock code :7157 yes
# Stock code :5184 yes
# Stock code :7204 yes
# Stock code :4456 yes
# Stock code :3484 yes
# Stock code :5276 yes
# Stock code :5216 yes
# Stock code :5141 yes
# Stock code :5132 yes
# Stock code :7277 yes
# Stock code :6947 yes
# Stock code :0131 yes
# Stock code :7528 yes
# Stock code :5908 yes
# Stock code :7114 yes
# Stock code :7169 yes
# Stock code :0205 yes
# Stock code :7198 yes
# Stock code :1619 yes
# Stock code :7233 yes
# Stock code :7148 yes
# Stock code :3948 yes
# Stock code :3026 yes
# Stock code :3417 yes
# Stock code :2143 yes
# Stock code :8206 yes
# Stock code :5283 yes
# Stock code :0239 yes
# Stock code :0227 yes
# Stock code :5253 yes
# Stock code :5036 yes
# Stock code :5208 yes
# Stock code :8877 yes
# Stock code :9016 yes
# Stock code :5228 yes
# Stock code :0090 yes
# Stock code :03025 yes
# Stock code :7149 yes
# Stock code :5056 yes
# Stock code :8613 yes
# Stock code :7217 cannot scrap
# Stock code :0100 cannot scrap
# Stock code :5081 cannot scrap
# Stock code :6815 cannot scrap
# Stock code :5101 cannot scrap
# Stock code :0190 cannot scrap
# Stock code :5205 cannot scrap
# Stock code :7249 cannot scrap
# Stock code :0065 cannot scrap
# Stock code :2984 cannot scrap
# Stock code :7047 cannot scrap
# Stock code :5029 cannot scrap
# Stock code :6041 cannot scrap
# Stock code :5306 cannot scrap
# Stock code :0084 cannot scrap
# Stock code :7229 cannot scrap
# Stock code :2755 cannot scrap
# Stock code :8605 cannot scrap
# Stock code :5222 cannot scrap
# Stock code :6939 cannot scrap
# Stock code :0149 cannot scrap
# Stock code :03026 cannot scrap
# Stock code :3107 cannot scrap
# Stock code :0231 cannot scrap
# Stock code :7210 cannot scrap
# Stock code :5197 cannot scrap
# Stock code :0157 cannot scrap
# Stock code :9172 cannot scrap
# Stock code :5277 cannot scrap
# Stock code :3689 cannot scrap
# Stock code :0128 cannot scrap
# Stock code :5226 cannot scrap
# Stock code :9261 cannot scrap
# Stock code :0206 cannot scrap
# Stock code :5398 cannot scrap
# Stock code :5209 cannot scrap
# Stock code :0198 cannot scrap
# Stock code :0078 cannot scrap
# Stock code :0104 cannot scrap
# Stock code :3182 cannot scrap
# Stock code :4715 cannot scrap
# Stock code :2291 cannot scrap
# Stock code :3204 cannot scrap
# Stock code :0039 cannot scrap
# Stock code :0021 cannot scrap
# Stock code :5220 cannot scrap
# Stock code :7022 cannot scrap
# Stock code :5020 cannot scrap
# Stock code :7382 cannot scrap
# Stock code :5649 cannot scrap
